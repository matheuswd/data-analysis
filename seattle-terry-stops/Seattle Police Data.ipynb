# %%
#Import necessary data
import numpy as np
import pandas as pd

# %%
stats = pd.read_csv('terry-stops.csv')

# %%
len(stats)
# Out:
# 26042

# %%
# É possivel pegar também o final (a cauda) dos dados
stats.tail()
# Out:
#       Subject Age Group  Subject ID     GO / SC Num  Terry Stop ID  \
# 26037           46 - 55     19931.0  20170000082254          26333
# 26038           26 - 35     19932.0  20170000000291          25557
# 26039           18 - 25     19933.0  20150000019672          26206
# 26040           26 - 35     19934.0  20160000322230          28528
# 26041           26 - 35     19935.0  20170000109195          26730
#
#                       Stop Resolution Weapon Type  Officer ID  Officer YOB  \
# 26037                       GO Report        None        2170       1975.0
# 26038                    Street Check        None        2223       1992.0
# 26039  Arrest with GO or Supplemental        None        2236       1986.0
# 26040  Arrest with GO or Supplemental        None        1792       1990.0
# 26041                       GO Report        None        1547       1982.0
#
#       Officer Gender        Officer Race ...      Reported Time  \
# ...

# %%
# informações sobre as colunas
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26042 entries, 0 to 26041
# Data columns (total 23 columns):
# Subject Age Group           26042 non-null object
# Subject ID                  25150 non-null float64
# GO / SC Num                 26042 non-null int64
# Terry Stop ID               26042 non-null int64
# Stop Resolution             26042 non-null object
# Weapon Type                 26042 non-null object
# Officer ID                  26042 non-null int64
# Officer YOB                 26025 non-null float64
# Officer Gender              26042 non-null object
# Officer Race                26042 non-null object
# Subject Perceived Race      26042 non-null object
# Subject Perceived Gender    26042 non-null object
# Reported Date               26042 non-null object
# Reported Time               26042 non-null object
# Initial Call Type           16188 non-null object
# Final Call Type             16188 non-null object
# Call Type                   16188 non-null object
# ...

# %%
#dá pra ver quais colunas também
stats.columns
# Out:
# Index(['Subject Age Group', 'Subject ID', 'GO / SC Num', 'Terry Stop ID',
#        'Stop Resolution', 'Weapon Type', 'Officer ID', 'Officer YOB',
#        'Officer Gender', 'Officer Race', 'Subject Perceived Race',
#        'Subject Perceived Gender', 'Reported Date', 'Reported Time',
#        'Initial Call Type', 'Final Call Type', 'Call Type', 'Officer Squad',
#        'Arrest Flag', 'Frisk Flag', 'Precinct', 'Sector', 'Beat'],
#       dtype='object')

# %%
#e tbm dá pra mudar o nome das colunas
stats.columns = ['SubjectAgeGroup', 'SubjectID', 'GOSCNum', 'TerryStopID',\
                 'StopResolution', 'WeaponType', 'OfficerID', 'OfficerYOB',\
                 'OfficerGender', 'OfficerRace', 'SubjectPerceivedRace', \
                 'SubjectPerceivedGender', 'ReportedDate', 'ReportedTime', \
                 'InitialCallType', 'FinalCallType', 'CallType', 'OfficerSquad', \
                 'ArrestFlag', 'FriskFlag', 'Precinct', 'Sector', 'Beat']

# %%
stats.columns
# Out:
# Index(['SubjectAgeGroup', 'SubjectID', 'GOSCNum', 'TerryStopID',
#        'StopResolution', 'WeaponType', 'OfficerID', 'OfficerYOB',
#        'OfficerGender', 'OfficerRace', 'SubjectPerceivedRace',
#        'SubjectPerceivedGender', 'ReportedDate', 'ReportedTime',
#        'InitialCallType', 'FinalCallType', 'CallType', 'OfficerSquad',
#        'ArrestFlag', 'FriskFlag', 'Precinct', 'Sector', 'Beat'],
#       dtype='object')

# %%
stats.head()
# Out:
#   SubjectAgeGroup  SubjectID         GOSCNum  TerryStopID StopResolution  \
# 0         36 - 45        NaN  20150000088359        10012              -
# 1         26 - 35        NaN  20150000087858        10068      GO Report
# 2         18 - 25        NaN  20150000001461        10103   Street Check
# 3         18 - 25        NaN  20150000001461        10104   Street Check
# 4         26 - 35        NaN  20150000103696        10207   Street Check
#
#   WeaponType  OfficerID  OfficerYOB OfficerGender OfficerRace ...   \
# 0       None       1735      1977.0             M       White ...
# 1       None       1561      1984.0             M       White ...
# 2       None       1539      1973.0             M       White ...
# 3       None       1539      1973.0             M       White ...
# 4       None       1539      1973.0             M       White ...
#
#        ReportedTime                                InitialCallType  \
# ...

# %%
stats.WeaponType.unique()
# Out:
# array(['None', 'Lethal Cutting Instrument', 'Handgun',
#        'Club, Blackjack, Brass Knuckles', '-', 'Blackjack',
#        'Firearm Other', 'Club', 'Firearm (unk type)', 'Shotgun',
#        'Brass Knuckles', 'Rifle'], dtype=object)

# %%
# Primeiro Filtro Simples
Filter = stats.WeaponType == 'Firearm (unk type)'

# %%
#Agora eu jogo o filtro dentro do stats e ele fará o filtro
stats[Filter]
# Out:
#       SubjectAgeGroup  SubjectID         GOSCNum  TerryStopID  \
# 5231          26 - 35     3430.0  20180000171661        40142
# 6504          18 - 25     4431.0  20180000225335        41263
# 6781          26 - 35     4654.0  20180000034890        37807
# 9481          26 - 35     6809.0  20170000000987        26460
# 9592          26 - 35     6879.0  20170000277674        36115
# 10037          1 - 17     7246.0  20150000338868        14823
# 12432         26 - 35     9129.0  20180000228707        41306
# 16958         26 - 35    12726.0  20170000341717        30402
# 18771         36 - 45    14194.0  20180000191924        40727
# 19329          1 - 17    14647.0  20150000175348        10912
# 23500         26 - 35    17893.0  20150000421479        16698
# 25794         26 - 35    19730.0  20150000006422        17311
#
#                        StopResolution          WeaponType  OfficerID  \
# 5231                     Street Check  Firearm (unk type)       2449
# ...

# %%
#Criando um filtro um pouquinho mais complexo
FilterWeapon = stats.WeaponType == 'Handgun'
FilterArrest = stats.ArrestFlag == 'Y'
FilterPrecinct = stats.Precinct == 'South'
FilterWeaponByArrest = stats[(FilterWeapon) & (FilterArrest) & (FilterPrecinct)]

# %%
FilterWeaponByArrest
# Out:
#       SubjectAgeGroup  SubjectID         GOSCNum  TerryStopID  \
# 216            1 - 17        NaN  20150000403385        16239
# 269            1 - 17        NaN  20160000005252        17481
# 1287          18 - 25      330.0  20160000046156        18318
# 1453          18 - 25      466.0  20160000046156        18315
# 1464           1 - 17      471.0  20160000373962        23710
# 2702          18 - 25     1469.0  20160000039642        18197
# 2868          18 - 25     1586.0  20170000157303        27349
# 2912          18 - 25     1620.0  20170000397945        31721
# 2923          26 - 35     1630.0  20160000111333        19432
# 3218          26 - 35     1863.0  20180000189396        40507
# 3579          18 - 25     2151.0  20150000249617        12886
# 3957          18 - 25     2431.0  20170000354072        30600
# 5199           1 - 17     3401.0  20150000429605        16728
# 6228          18 - 25     4216.0  20160000252396        21838
# ...

# %%
FilterWeapon = stats.WeaponType != 'None'

handgunDF = stats[FilterWeapon]
handgunDF.WeaponType
# Out:
# 24             Lethal Cutting Instrument
# 41             Lethal Cutting Instrument
# 106            Lethal Cutting Instrument
# 198            Lethal Cutting Instrument
# 216                              Handgun
# 249            Lethal Cutting Instrument
# 250            Lethal Cutting Instrument
# 269                              Handgun
# 314            Lethal Cutting Instrument
# 355            Lethal Cutting Instrument
# 422            Lethal Cutting Instrument
# 429            Lethal Cutting Instrument
# 450            Lethal Cutting Instrument
# 455            Lethal Cutting Instrument
# 462            Lethal Cutting Instrument
# 469            Lethal Cutting Instrument
# 519            Lethal Cutting Instrument
# 555            Lethal Cutting Instrument
# 557            Lethal Cutting Instrument
# 559            Lethal Cutting Instrument
# 663            Lethal Cutting Instrument
# 674      Club, Blackjack, Brass Knuckles
# 709                                    -
# ...

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26042 entries, 0 to 26041
# Data columns (total 23 columns):
# SubjectAgeGroup           26042 non-null object
# SubjectID                 25150 non-null float64
# GOSCNum                   26042 non-null int64
# TerryStopID               26042 non-null int64
# StopResolution            26042 non-null object
# WeaponType                26042 non-null object
# OfficerID                 26042 non-null int64
# OfficerYOB                26025 non-null float64
# OfficerGender             26042 non-null object
# OfficerRace               26042 non-null object
# SubjectPerceivedRace      26042 non-null object
# SubjectPerceivedGender    26042 non-null object
# ReportedDate              26042 non-null object
# ReportedTime              26042 non-null object
# InitialCallType           16188 non-null object
# FinalCallType             16188 non-null object
# CallType                  16188 non-null object
# ...

# %%
stats.WeaponType = stats.WeaponType.astype("category")
stats.OfficerGender = stats.OfficerGender.astype("category")
stats.OfficerRace = stats.OfficerRace.astype("category")
stats.ArrestFlag = stats.ArrestFlag.astype("category")
stats.FriskFlag = stats.FriskFlag.astype("category")
stats.Precinct = stats.Precinct.astype("category")
stats.Sector = stats.Sector.astype("category")
stats.Beat = stats.Beat.astype("category")

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26042 entries, 0 to 26041
# Data columns (total 23 columns):
# SubjectAgeGroup           26042 non-null object
# SubjectID                 25150 non-null float64
# GOSCNum                   26042 non-null int64
# TerryStopID               26042 non-null int64
# StopResolution            26042 non-null object
# WeaponType                26042 non-null category
# OfficerID                 26042 non-null int64
# OfficerYOB                26025 non-null float64
# OfficerGender             26042 non-null category
# OfficerRace               26042 non-null category
# SubjectPerceivedRace      26042 non-null object
# SubjectPerceivedGender    26042 non-null object
# ReportedDate              26042 non-null object
# ReportedTime              26042 non-null object
# InitialCallType           16188 non-null object
# FinalCallType             16188 non-null object
# CallType                  16188 non-null object
# ...

# %%
stats.describe()
# Out:
#           SubjectID       GOSCNum   TerryStopID     OfficerID    OfficerYOB
# count  25150.000000  2.604200e+04  26042.000000  26042.000000  26025.000000
# mean    9961.973519  2.016325e+13  24524.799017   1706.668036   1981.002997
# std     5751.164334  1.053838e+10   9080.115744    562.876652      8.807061
# min        4.000000  2.009000e+13  10010.000000     -9.000000   1900.000000
# 25%     4947.250000  2.015000e+13  16920.250000   1562.000000   1976.000000
# 50%     9928.000000  2.016000e+13  23616.500000   1775.000000   1983.000000
# 75%    14974.750000  2.017000e+13  30403.750000   2103.000000   1987.000000
# max    19935.000000  2.018000e+13  41887.000000   4883.000000   1996.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
handgunDF = stats[FilterWeapon]
len(handgunDF)
# Out:
# 1450

# %%
newGuns = stats[["WeaponType", "Precinct"]].copy()
len(newGuns)
# Out:
# 26042

# %%
newdf = newGuns[(newGuns.WeaponType != 'None') & (newGuns.WeaponType != '-')]

# %%
newdf
# Out:
#                             WeaponType   Precinct
# 24           Lethal Cutting Instrument       West
# 41           Lethal Cutting Instrument        NaN
# 106          Lethal Cutting Instrument        NaN
# 198          Lethal Cutting Instrument      North
# 216                            Handgun      South
# 249          Lethal Cutting Instrument        NaN
# 250          Lethal Cutting Instrument      South
# 269                            Handgun      South
# 314          Lethal Cutting Instrument      South
# 355          Lethal Cutting Instrument  Southwest
# 422          Lethal Cutting Instrument        NaN
# 429          Lethal Cutting Instrument      South
# 450          Lethal Cutting Instrument       West
# 455          Lethal Cutting Instrument  Southwest
# 462          Lethal Cutting Instrument        NaN
# 469          Lethal Cutting Instrument        NaN
# 519          Lethal Cutting Instrument        NaN
# 555          Lethal Cutting Instrument       West
# ...

# %%
FilterWeapon = stats.WeaponType == 'Handgun'

FilterWeaponByArrest = stats[(FilterWeapon)]
FilterWeaponByArrest
# Out:
#       SubjectAgeGroup  SubjectID         GOSCNum  TerryStopID  \
# 216            1 - 17        NaN  20150000403385        16239
# 269            1 - 17        NaN  20160000005252        17481
# 1086          18 - 25      164.0  20160000207066        21084
# 1126          36 - 45      194.0  20160000053933        18449
# 1127          18 - 25      195.0  20170000265310        29004
# 1287          18 - 25      330.0  20160000046156        18318
# 1434          18 - 25      448.0  20170000357478        30641
# 1453          18 - 25      466.0  20160000046156        18315
# 1464           1 - 17      471.0  20160000373962        23710
# 1688          26 - 35      666.0  20170000104492        26654
# 1922          18 - 25      848.0  20170000390524        31985
# 1978          26 - 35      897.0  20160000004330        23556
# 1996          26 - 35      914.0  20150000139484        10426
# 2121          36 - 45     1012.0  20160000019228        19731
# ...

# %%
getWeaponType = stats.WeaponType.unique()

newdf = pd.DataFrame({"TipoDeArma": np.array(getWeaponType) })

# %%
newdf
# Out:
#                          TipoDeArma
# 0                              None
# 1         Lethal Cutting Instrument
# 2                           Handgun
# 3   Club, Blackjack, Brass Knuckles
# 4                                 -
# 5                         Blackjack
# 6                     Firearm Other
# 7                              Club
# 8                Firearm (unk type)
# 9                           Shotgun
# 10                   Brass Knuckles
# 11                            Rifle

# %%
stats
# Out:
#       Subject Age Group  Subject ID     GO / SC Num  Terry Stop ID  \
# 0               36 - 45         NaN  20150000088359          10012
# 1               26 - 35         NaN  20150000087858          10068
# 2               18 - 25         NaN  20150000001461          10103
# 3               18 - 25         NaN  20150000001461          10104
# 4               26 - 35         NaN  20150000103696          10207
# 5                     -         NaN  20150000001670          10209
# 6               26 - 35         NaN  20150000001824          10289
# 7               26 - 35         NaN  20150000001824          10290
# 8               36 - 45         NaN  20150000002031          10403
# 9               46 - 55         NaN  20150000002051          10415
# 10         56 and Above         NaN  20150000002107          10429
# 11         56 and Above         NaN  20150000002126          10433
# 12              18 - 25         NaN  20150000140597          10440
# ...

# %%
stats = stats.dropna(axis=0)

# %%
len(stats)
# Out:
# 15533

# %%
# Out:
#       Subject Age Group  Subject ID     GO / SC Num  Terry Stop ID  \
# 894             46 - 55         6.0  20180000097451          39041
# 895             46 - 55        13.0  20180000173186          40227
# 899             18 - 25        17.0  20150000384509          15897
# 901             36 - 45        19.0  20150000397582          16150
# 902             26 - 35        21.0  20150000337890          14843
# 904              1 - 17        23.0  20170000425208          33261
# 905             26 - 35        24.0  20160000048068          18362
# 907             18 - 25        26.0  20150000187319          11280
# 908             18 - 25        26.0  20150000248379          12867
# 909             18 - 25        26.0  20150000187319          17161
# 912             26 - 35        27.0  20170000095506          26483
# 913             26 - 35        28.0  20150000268790          13445
# 914             26 - 35        28.0  20150000268790          17126
# ...
