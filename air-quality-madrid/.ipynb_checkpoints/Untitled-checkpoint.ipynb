# %%
import pandas as pd
import numpy as np

# %%
stations = pd.read_csv('./stations.csv')
y2001 = pd.read_csv('./csvs_per_year/madrid_2001.csv')

stations.head()
# Out:
#          id                 name  \
# 0  28079004       Pza. de España
# 1  28079008     Escuelas Aguirre
# 2  28079011  Avda. Ramón y Cajal
# 3  28079016         Arturo Soria
# 4  28079017           Villaverde
#
#                                              address       lon        lat  \
# 0                                    Plaza de España -3.712247  40.423853
# 1                    Entre C/ Alcalá y C/ O’ Donell  -3.682319  40.421564
# 2   Avda. Ramón y Cajal  esq. C/ Príncipe de Vergara -3.677356  40.451475
# 3  C/ Arturo Soria  esq. C/  Vizconde de los Asilos  -3.639233  40.440047
# 4                                  C/. Juan Peñalver -3.713322  40.347139
#
#    elevation
# 0        635
# 1        670
# 2        708
# 3        693
# 4        604

# %%
# y2001 = y2001.dropna()

# %%
filter1 = y2001.date == '2001-08-01 01:00:00'
y2001[filter1].BEN.sum()
# Out:
# 5.6999998688697815

# %%
y2001_agg = y2001[['date', 'BEN']].groupby(by='date').sum()
y2001_agg
# Out:
#                            BEN
# date
# 2001-01-01 01:00:00   9.350000
# 2001-01-01 02:00:00  16.740000
# 2001-01-01 03:00:00  29.250000
# 2001-01-01 04:00:00  30.940001
# 2001-01-01 05:00:00  22.350000
# 2001-01-01 06:00:00  13.110000
# 2001-01-01 07:00:00  10.240000
# 2001-01-01 08:00:00  11.040000
# 2001-01-01 09:00:00  13.240000
# 2001-01-01 10:00:00  11.160000
# 2001-01-01 11:00:00   9.110000
# 2001-01-01 12:00:00   6.500000
# 2001-01-01 13:00:00   6.830000
# 2001-01-01 14:00:00   8.660000
# 2001-01-01 15:00:00  12.730000
# 2001-01-01 16:00:00  13.390000
# 2001-01-01 17:00:00   8.140000
# 2001-01-01 18:00:00   7.620000
# 2001-01-01 19:00:00  15.420000
# 2001-01-01 20:00:00  17.760000
# 2001-01-01 21:00:00  15.180000
# 2001-01-01 22:00:00  16.110000
# 2001-01-01 23:00:00  11.580000
# 2001-01-02 00:00:00  10.880000
# 2001-01-02 01:00:00   6.040000
# 2001-01-02 02:00:00   5.050000
# 2001-01-02 03:00:00   3.810000
# 2001-01-02 04:00:00   2.700000
# 2001-01-02 05:00:00   2.310000
# ...

# %%
filter1 = y2001.date == '2001-08-01 03:00:00'
y2001[filter1].BEN.sum()
# Out:
# 4.040000081062317
